# %%
def func(x,y=[]):
    y.append(x)
    return y

print(func(1))
print(func(2,[]))
print(func(3))
# Out:
# [1]
# [2]
# [1, 3]

# %%
a = (1,2,3)
print(a * 3)

b = (1,2,3)
print(a is b)
# Out:
# (1, 2, 3, 1, 2, 3, 1, 2, 3)
# False

# %%
for i in range(5):
    if i == 3:
        break
    else:
        print("C")
# Out:
# C
# C
# C

# %%
a = {1,2,3}
b = {3,4,5}

print(a & b)
# Out:
# {3}

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 nonl
#
# NameError: name 'nonl' is not defined

# %%
x = [1,2,3,4,5]
print(x[::2])
# Out:
# [1, 3, 5]

# %%
a = dict()
